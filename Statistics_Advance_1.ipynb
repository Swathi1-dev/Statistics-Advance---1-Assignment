# %% [markdown]
# Theory
#
# 1. What is a random variable in probability theory?
#
# Ans: A variable that takes numerical values based on outcomes of an random phenomenon.
# EG: while tossing a coin we have two values H(1) and T(0) , random variable will store 0 and 1 in it.
#
# 2. What are the types of random variables?
#
# ANs: 1.discrete 2.continuous
#
# 3.  What is the difference between discrete and continuous distributions?
#
# Ans: Discrete are countable values , finite data outcomes, continuos are infinite outcomes and it is uncountable.
#
# 4.  What are probability distribution functions (PDF)?
#
# Ans: A function which describes a random variable taking specific values.
#
# 5.  How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
#
# Ans: cumulative provides the distribution for all the probability and probability shows probability for specific values.
#
# 6.  What is a discrete uniform distribution?
#
# Ans: If the outcomes are discrete and all the probability is equal for all the outcomes then it is known as discrete uniform distribution.
#
# 7.  What are the key properties of a Bernoulli distribution?
#
# Ans: it have only 2 outcomes with a fixed probability .
#
# 8.  What is the binomial distribution, and how is it used in probability?
#
# Ans: It have only 2 outcomes and n number of trails. it finds how many times we got specific outcome in n number of trails.
#
# 9.  What is the Poisson distribution and where is it applied?
#
# Ans: Poisson distribution is an type of mass function it finds the n number of events in an fixed interval , used in event count problems.
#
# 10.  What is a continuous uniform distribution?
#
# Ans:  If the outcomes are continuous and all the probability is equal for all the outcomes then it is known as continuous uniform distribution.
#
# 11.  What are the characteristics of a normal distribution?
#
# Ans: It is defined by mean and standard distribution , where the mean and statndard deviation might be different for each distribution.
#
# 12.  What is the standard normal distribution, and why is it important?
#
# Ans: In standard normal distribution the mean is 0 and standard deviation is 1.used for standardizing data.
#
# 13.  What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#
# Ans: CLT states sample means approximate a normal distribution as sample size increases , regardless of original distribtuion.
#
# 14.  How does the Central Limit Theorem relate to the normal distribution?
#
# Ans: It justifies using the normal distribution for inference about sample means.
#
# 15.  What is the application of Z statistics in hypothesis testing?
#
# Ans: It is used to determine how far a sample mean is from the population mean.
#
# 16.  How do you calculate a Z-score, and what does it represen?
#
# Ans:  using mean , data and standard deviation we will found z-score . it shows how many SDs a vakue is form the mean.
#
# 17.  What are point estimates and interval estimates in statistics?
#
# Ans: Point estimates give a single value and interval estimates give a range of valies.
#
#
# 18.  What is the significance of confidence intervals in statistical analysis?
#
# Ans: They provide a range within which the population parameter likely lies.
#
# 19.  What is the relationship between a Z-score and a confidence interval?
#
# Ans: z score determines the critical values for constructing confirdence intervals.
#
# 20.  How are Z-scores used to compare different distributions?
#
# Ans: They standadize the values, allowing comparison across different distributions.
#
# 21.  What are the assumptions for applying the Central Limit Theorem?
#
# Ans: The sample should be big , the sample size should be greter than 30 .
#
# 22.  What is the concept of expected value in a probability distribution?
#
# Ans: The long-run average of a random variables's , weighted by probability.
#
# 23.  How does a probability distribution relate to the expected outcome of a random variable?
#
# Ans: It helps calculating the expected value, representing the average outcomes over many trials.
